# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json
import pandas as pd

url = "https://servicodados.ibge.gov.br/api/v1/localidades/estados/33|35/distritos"
dados = requests.get(url).content
js = json.loads(dados.decode("utf-8"))
table = pd.json_normalize(js)
table.head(1000)
# Out:
#             id                   nome  municipio.id        municipio.nome  \
# 0    350010505             Adamantina       3500105            Adamantina
# 1    350020405                 Adolfo       3500204                Adolfo
# 2    350030305                  Aguaí       3500303                 Aguaí
# 3    350040205         Águas da Prata       3500402        Águas da Prata
# 4    350040210   São Roque da Fartura       3500402        Águas da Prata
# ..         ...                    ...           ...                   ...
# 995  354700705   Santa Maria da Serra       3547007  Santa Maria da Serra
# 996  330460705   Santa Maria Madalena       3304607  Santa Maria Madalena
# 997  330460710          Doutor Loréti       3304607  Santa Maria Madalena
# 998  330460715             Renascença       3304607  Santa Maria Madalena
# 999  330460720  Santo Antônio do Imbé       3304607  Santa Maria Madalena
#
#      municipio.microrregiao.id municipio.microrregiao.nome  \
# ...

# %%
import io
import requests
import pandas as pd

#Alertas Dengue RJ - Dengue
url = "https://info.dengue.mat.br/api/alertcity?geocode=3304557&disease=dengue&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
csv.head()
# Out:
#    data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0  2021-08-01  202131       17.0              9             31      6
# 1  2021-08-08  202132       19.0              9             40      4
#
#       p_rt1  p_inc100k  Localidade_id  nivel  ...  versao_modelo tweet   Rt  \
# 0  0.251283   0.251933              0      1  ...     2021-08-17   4.0  1.0
# 1  0.595414   0.281573              0      1  ...     2021-08-17   2.0  1.0
#
#          pop  tempmin  umidmax  receptivo  transmissao  nivel_inc  \
# 0  6747815.0     15.0      NaN          0            0          0
# 1  6747815.0     17.0      NaN          0            0          0
#
#    notif_accum_year
# 0               952
# 1               952
#
# [2 rows x 21 columns]

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
